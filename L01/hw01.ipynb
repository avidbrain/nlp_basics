# %% [markdown]
# # Введение в обработку естественного языка

# %% [markdown]
# ## Урок 1. Предобработка текста

# %% [markdown]
# **Примечания**:
# - словари `apostrophe_dict`, `short_word_dict` и `emoticon_dict` вынесены в hw01_helper.py
# - csv файлы вынесены в директорию "../data"
# - для работы с текстом по возможности использована функциональность pandas.Series.str как более векторизованная

# %%
import numpy as np
import pandas as pd
import nltk

# %%
pd.set_option('max_colwidth', 150)

# %% [markdown]
# ### Вспомогательные словари

# %%
from hw01_helper import apostrophe_dict as apostrophe_dict_lib, short_word_dict, emoticon_dict

# %%
# В apostrophe_dict в значении указаны варианты, например: 'am not / are not'
# Это избыточно для целей замены сокращений, оставим только первое значение.
apostrophe_dict = {k: v.split('/')[0].strip() for k, v in apostrophe_dict_lib.items()}

# %% [markdown]
# ### Данные

# %%
TRAIN_PATH = "../data/train_tweets.csv"
TEST_PATH = "../data/test_tweets.csv"
PROCESSED_PATH = "../data/tweets.pkl.gz"

# %%
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
combine_df = train_df.append(test_df, ignore_index = True, sort = False)
combine_df.shape
# Out:
# (49159, 3)

# %% [markdown]
# ### Обработка

# %%
df00 = combine_df.assign(text=lambda x: x.tweet)

# %% [markdown]
# ---
# 1. Удалим @user из всех твитов с помощью паттерна "@[\w]*".

# %%
df01 = df00.assign(text=lambda x: x.text.str.replace(r'@\w+', '', regex=True))
df01.head(5)
# Out:
#    id  label  \
# 0   1    0.0
# 1   2    0.0
# 2   3    0.0
# 3   4    0.0
# 4   5    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                      factsguide: society now    #motivation
#
#                                                                                                                text
# 0                   when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1    thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                               bihday your majesty
# 3                            #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                            factsguide: society now    #motivation

# %% [markdown]
# ---
# 2. Изменим регистр твитов на нижний с помощью .lower()

# %%
df02 = df01.assign(text=lambda x: x.text.str.lower())

# %% [markdown]
# ---
# 3. Заменим сокращения с апострофами (пример: ain't, can't), используя apostrophe_dict.

# %%
# эти сокращения ещё называются "short/contracted forms of the modal verbs"
def dictionary_replace(string, lookup):
    return ' '.join(lookup.get(word,word) for word in string.split())

# %%
df03 = df02.assign(text=lambda x: x.text.apply(dictionary_replace, lookup=apostrophe_dict))
df03.head(3)
# Out:
#    id  label  \
# 0   1    0.0
# 1   2    0.0
# 2   3    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
#
#                                                                                                             text
# 0                  when a father is dysfunctional and is so selfish he drags his kids into his dysfunction. #run
# 1  thanks for #lyft credit i cannot use cause they do not offer wheelchair vans in pdx. #disapointed #getthanked
# 2                                                                                            bihday your majesty

# %% [markdown]
# ---
# 4. Заменим сокращения на их полные формы, используя short_word_dict. Для этого воспользуемся функцией, используемой в предыдущем пункте.

# %%
df04 = df03.assign(text=lambda x: x.text.apply(dictionary_replace, lookup=short_word_dict))
# С таким простым подходом не все получится заменить. Например, "omg!!!" не заменится на "oh my god!!!"
df04.iloc[[94, 4426]]
# Out:
#         id  label  \
# 94      95    0.0
# 4426  4427    0.0
#
#                                                                                                                  tweet  \
# 94    omg!!! loving this station!!! way to jam out at work!!! while getting work done of course!!!!   #memories @user
# 4426          thanx ð @user #love #couple #cute #adorable #hugs #romance #forever #girlfriend    #smile #beautiful
#
#                                                                                                          text
# 94    omg!!! loving this station!!! way to jam out at work!!! while getting work done of course!!!! #memories
# 4426          thanks ð #love #couple #cute #adorable #hugs #romance #forever #girlfriend #smile #beautiful

# %% [markdown]
# ---
# 5. Заменим эмотиконы (пример: ":)" = "happy"), используя emoticon_dict. Для этого воспользуемся функцией, используемой в предыдущем пункте.

# %%
df05 = df04.assign(text=lambda x: x.text.apply(dictionary_replace, lookup=emoticon_dict))
df05.iloc[[63, 128]]
# Out:
#       id  label  \
# 63    64    0.0
# 128  129    0.0
#
#                                                                                             tweet  \
# 63                                                              you've really hu my feelings :(
# 128  yeah! new buttons in the mail for me ð  they are so pretty! :) #jewelrymaking #buttons
#
#                                                                                             text
# 63                                                            you have really hu my feelings sad
# 128  yeah! new buttons in the mail for me ð they are so pretty! happy #jewelrymaking #buttons

# %% [markdown]
# ---
# 6. Заменим пунктуацию на пробелы, используя re.sub() и паттерн r'[^\w\s]'

# %%
df06 = df05.assign(text=lambda x: x.text.str.replace(r'[^\w\s]', ' ', regex=True))
df06.head(4)
# Out:
#    id  label  \
# 0   1    0.0
# 1   2    0.0
# 2   3    0.0
# 3   4    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
#
#                                                                                                             text
# 0                  when a father is dysfunctional and is so selfish he drags his kids into his dysfunction   run
# 1  thanks for  lyft credit i cannot use cause they do not offer wheelchair vans in pdx   disapointed  getthanked
# 2                                                                                            bihday your majesty
# 3                          model i love you take with you all the time in urð       ð   ð   ð   ð   ð   ð   ð

# %% [markdown]
# ---
# 7. Заменим спец. символы на пробелы, используя re.sub() и паттерн r'[^a-zA-Z0-9]'

# %%
df07 = df06.assign(text=lambda x: x.text.str.replace(r'[^a-zA-Z0-9]', repl=' ', regex=True))
df07.iloc[48003:48005]
# Out:
#           id  label  \
# 48003  48004    NaN
# 48004  48005    NaN
#
#                                                                                                            tweet  \
# 48003                     @user me &amp; @user off to @user fri 22/7 @user to see @user @user @user plus otheâ¦
# 48004  run when you can, walk if you have to, crawl if u must; just never give up~! ð«ð«âºï¸   #sundayâ¦
#
#                                                                                                            text
# 48003                                                              me  amp  off to fri 22 7 to see plus othe
# 48004  run when you can  walk if you have to  crawl if you must  just never give up                   sunday

# %% [markdown]
# ---
# 8. Заменим числа на пробелы, используя re.sub() и паттерн r'[^a-zA-Z]'

# %%
df08 = df07.assign(text=lambda x: x.text.str.replace(r'[^a-zA-Z]', repl=' ', regex=True))
df08.iloc[[50, 48003]]
# Out:
#           id  label  \
# 50        51    0.0
# 48003  48004    NaN
#
#                                                                                          tweet  \
# 50                #abc2020 getting ready 2 remove the victums frm #pulseclub #prayfororlando
# 48003   @user me &amp; @user off to @user fri 22/7 @user to see @user @user @user plus otheâ¦
#
#                                                                              text
# 50      abc     getting ready   remove the victums frm  pulseclub  prayfororlando
# 48003                                me  amp  off to fri      to see plus othe

# %% [markdown]
# ---
# 9. Удалим из текста слова длиной в 1 символ, используя ' '.join([w for w in x.split() if len(w)>1])

# %%
# Немного более общая реализация
def filter_words(words, function=None):
    if isinstance(words, str):
        return ' '.join(filter(function, words.split()))
    return list(filter(function, words))

# %%
df09 = df08.assign(text=lambda x: x.text.apply(filter_words, function=lambda x: len(x)>1))
df09.head(2)
# Out:
#    id  label  \
# 0   1    0.0
# 1   2    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
#
#                                                                                                       text
# 0                when father is dysfunctional and is so selfish he drags his kids into his dysfunction run
# 1  thanks for lyft credit cannot use cause they do not offer wheelchair vans in pdx disapointed getthanked

# %% [markdown]
# ---
# 10. Поделим твиты на токены с помощью nltk.tokenize.word_tokenize, создав новый столбец 'tweet_token'.

# %%
# %%time
df10 = df09.assign(tweet_token=lambda x: x.text.apply(nltk.tokenize.word_tokenize))
df10.head(2)
# Out:
# Wall time: 10.3 s
#    id  label  \
# 0   1    0.0
# 1   2    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
#
#                                                                                                       text  \
# 0                when father is dysfunctional and is so selfish he drags his kids into his dysfunction run
# 1  thanks for lyft credit cannot use cause they do not offer wheelchair vans in pdx disapointed getthanked
#
#                                                                                                                    tweet_token
# 0                   [when, father, is, dysfunctional, and, is, so, selfish, he, drags, his, kids, into, his, dysfunction, run]
# 1  [thanks, for, lyft, credit, can, not, use, cause, they, do, not, offer, wheelchair, vans, in, pdx, disapointed, getthanked]

# %% [markdown]
# ---
# 11. Удалим стоп-слова из токенов, используя nltk.corpus.stopwords. Создадим столбец 'tweet_token_filtered' без стоп-слов.

# %%
stopwords = set(nltk.corpus.stopwords.words("english"))

# %%
df11 = df10.assign(tweet_token_filtered=lambda x: x.tweet_token.apply(filter_words, 
                                                                      function=lambda x: x not in stopwords))
df11.head(2)
# Out:
#    id  label  \
# 0   1    0.0
# 1   2    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
#
#                                                                                                       text  \
# 0                when father is dysfunctional and is so selfish he drags his kids into his dysfunction run
# 1  thanks for lyft credit cannot use cause they do not offer wheelchair vans in pdx disapointed getthanked
#
#                                                                                                                    tweet_token  \
# 0                   [when, father, is, dysfunctional, and, is, so, selfish, he, drags, his, kids, into, his, dysfunction, run]
# 1  [thanks, for, lyft, credit, can, not, use, cause, they, do, not, offer, wheelchair, vans, in, pdx, disapointed, getthanked]
#
#                                                                         tweet_token_filtered
# 0                            [father, dysfunctional, selfish, drags, kids, dysfunction, run]
# 1  [thanks, lyft, credit, use, cause, offer, wheelchair, vans, pdx, disapointed, getthanked]

# %% [markdown]
# ---
# 12. Применим стемминг к токенам с помощью nltk.stem.PorterStemmer. Создадим столбец 'tweet_stemmed' после применения стемминга.

# %%
stemmer = nltk.stem.PorterStemmer()

# %%
def transform_words(words, function):
    if isinstance(words, str):
        return ' '.join(map(function, words.split()))
    return list(map(function, words))

# %%
# %%time
df12 = df11.assign(tweet_stemmed=lambda x: x.tweet_token_filtered.apply(transform_words,
                                                                        function=stemmer.stem))
df12.head(2)
# Out:
# Wall time: 14 s
#    id  label  \
# 0   1    0.0
# 1   2    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
#
#                                                                                                       text  \
# 0                when father is dysfunctional and is so selfish he drags his kids into his dysfunction run
# 1  thanks for lyft credit cannot use cause they do not offer wheelchair vans in pdx disapointed getthanked
#
#                                                                                                                    tweet_token  \
# 0                   [when, father, is, dysfunctional, and, is, so, selfish, he, drags, his, kids, into, his, dysfunction, run]
# 1  [thanks, for, lyft, credit, can, not, use, cause, they, do, not, offer, wheelchair, vans, in, pdx, disapointed, getthanked]
#
#                                                                         tweet_token_filtered  \
# 0                            [father, dysfunctional, selfish, drags, kids, dysfunction, run]
# 1  [thanks, lyft, credit, use, cause, offer, wheelchair, vans, pdx, disapointed, getthanked]
#
#                                                                         tweet_stemmed
# 0                               [father, dysfunct, selfish, drag, kid, dysfunct, run]
# 1  [thank, lyft, credit, use, caus, offer, wheelchair, van, pdx, disapoint, getthank]

# %%
# Faster implementation with memory cache
def transform_series_words(series, function):
    unique_words = set(series.explode(ignore_index=True))
    cache = {w:function(w) for w in unique_words if isinstance(w, str)}
    return series.apply(lambda words: [cache[w] for w in words if w in cache])

# %%
# %%time
df12 = df11.assign(tweet_stemmed=lambda x: transform_series_words(x.tweet_token_filtered,
                                                                  function=stemmer.stem))
df12.head(2)
# Out:
# Wall time: 2.02 s
#    id  label  \
# 0   1    0.0
# 1   2    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
#
#                                                                                                       text  \
# 0                when father is dysfunctional and is so selfish he drags his kids into his dysfunction run
# 1  thanks for lyft credit cannot use cause they do not offer wheelchair vans in pdx disapointed getthanked
#
#                                                                                                                    tweet_token  \
# 0                   [when, father, is, dysfunctional, and, is, so, selfish, he, drags, his, kids, into, his, dysfunction, run]
# 1  [thanks, for, lyft, credit, can, not, use, cause, they, do, not, offer, wheelchair, vans, in, pdx, disapointed, getthanked]
#
#                                                                         tweet_token_filtered  \
# 0                            [father, dysfunctional, selfish, drags, kids, dysfunction, run]
# 1  [thanks, lyft, credit, use, cause, offer, wheelchair, vans, pdx, disapointed, getthanked]
#
#                                                                         tweet_stemmed
# 0                               [father, dysfunct, selfish, drag, kid, dysfunct, run]
# 1  [thank, lyft, credit, use, caus, offer, wheelchair, van, pdx, disapoint, getthank]

# %% [markdown]
# ---
# 13. Применим лемматизацию к токенам с помощью nltk.stem.wordnet.WordNetLemmatizer. Создадим столбец 'tweet_lemmatized' после применения лемматизации.

# %%
lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()

# %%
# %%time
df13 = df12.assign(tweet_lemmatized=lambda x: transform_series_words(x.tweet_token_filtered,
                                                                     function=lemmatizer.lemmatize))
df13.head(2)
# Out:
# Wall time: 4.11 s
#    id  label  \
# 0   1    0.0
# 1   2    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
#
#                                                                                                       text  \
# 0                when father is dysfunctional and is so selfish he drags his kids into his dysfunction run
# 1  thanks for lyft credit cannot use cause they do not offer wheelchair vans in pdx disapointed getthanked
#
#                                                                                                                    tweet_token  \
# 0                   [when, father, is, dysfunctional, and, is, so, selfish, he, drags, his, kids, into, his, dysfunction, run]
# 1  [thanks, for, lyft, credit, can, not, use, cause, they, do, not, offer, wheelchair, vans, in, pdx, disapointed, getthanked]
#
#                                                                         tweet_token_filtered  \
# 0                            [father, dysfunctional, selfish, drags, kids, dysfunction, run]
# 1  [thanks, lyft, credit, use, cause, offer, wheelchair, vans, pdx, disapointed, getthanked]
#
#                                                                         tweet_stemmed  \
# 0                               [father, dysfunct, selfish, drag, kid, dysfunct, run]
# 1  [thank, lyft, credit, use, caus, offer, wheelchair, van, pdx, disapoint, getthank]
#
#                                                                            tweet_lemmatized
# 0                             [father, dysfunctional, selfish, drag, kid, dysfunction, run]
# 1  [thanks, lyft, credit, use, cause, offer, wheelchair, van, pdx, disapointed, getthanked]

# %% [markdown]
# ### Обработка как последовательность действий в pandas

# %%
# %%time
df = (
    combine_df
    .assign(text=lambda x: x.tweet)
    .assign(text=lambda x: x.text.str.replace(r'@\w+', '', regex=True))
    .assign(text=lambda x: x.text.str.lower())
    .assign(text=lambda x: x.text.apply(dictionary_replace, lookup=apostrophe_dict))
    .assign(text=lambda x: x.text.apply(dictionary_replace, lookup=short_word_dict))
    .assign(text=lambda x: x.text.apply(dictionary_replace, lookup=emoticon_dict))
    .assign(text=lambda x: x.text.str.replace(r'[^\w\s]', ' ', regex=True))
    .assign(text=lambda x: x.text.str.replace(r'[^a-zA-Z0-9]', repl=' ', regex=True))
    .assign(text=lambda x: x.text.str.replace(r'[^a-zA-Z]', repl=' ', regex=True))
    .assign(text=lambda x: x.text.apply(filter_words, function=lambda x: len(x)>1))
    .assign(tweet_token=lambda x: x.text.apply(nltk.tokenize.word_tokenize))
    .assign(tweet_token_filtered=lambda x: x.tweet_token.apply(filter_words,
                                                               function=lambda x: x not in stopwords))
    .assign(tweet_stemmed=lambda x: transform_series_words(x.tweet_token_filtered,
                                                           function=stemmer.stem))
    .assign(tweet_lemmatized=lambda x: transform_series_words(x.tweet_token_filtered,
                                                              function=lemmatizer.lemmatize))
)
df
# Out:
# Wall time: 15.7 s
#           id  label  \
# 0          1    0.0
# 1          2    0.0
# 2          3    0.0
# 3          4    0.0
# 4          5    0.0
# ...      ...    ...
# 49154  49155    NaN
# 49155  49156    NaN
# 49156  49157    NaN
# 49157  49158    NaN
# 49158  49159    NaN
#
#                                                                                                                                                    tweet  \
# 0                                                  @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1                             @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                                                    bihday your majesty
# 3                                                                 #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                                                 factsguide: society now    #motivation
# ...                                                                                                                                                  ...
# 49154                                       thought factory: left-right polarisation! #trump #uselections2016 #leadership #politics  #brexit #blm &gt;3
# 49155                                                   feeling like a mermaid ð #hairflip #neverready #formal #wedding #gown #dresses #mermaid  â¦
# 49156  #hillary #campaigned today in #ohio((omg)) &amp; used words like "assets&amp;liability" never once did #clinton say thee(word) #radicalization
# 49157                                           happy, at work conference: right mindset leads to culture-of-development organizations    #work #mindset
# 49158                                                                                   my   song "so glad" free download!  #shoegaze #newmusic #newsong
#
#                                                                                                                                     text  \
# 0                                              when father is dysfunctional and is so selfish he drags his kids into his dysfunction run
# 1                                thanks for lyft credit cannot use cause they do not offer wheelchair vans in pdx disapointed getthanked
# 2                                                                                                                    bihday your majesty
# 3                                                                                        model love you take with you all the time in ur
# 4                                                                                                      factsguide society now motivation
# ...                                                                                                                                  ...
# 49154                                        thought factory left right polarisation trump uselections leadership politics brexit blm gt
# 49155                                                       feeling like mermaid hairflip neverready formal wedding gown dresses mermaid
# 49156  hillary campaigned today in ohio omg amp used words like assets amp liability never once did clinton say thee word radicalization
# 49157                                  happy at work conference right mindset leads to culture of development organizations work mindset
# 49158                                                                            my song so glad free download shoegaze newmusic newsong
#
#                                                                                                                                                  tweet_token  \
# 0                                                 [when, father, is, dysfunctional, and, is, so, selfish, he, drags, his, kids, into, his, dysfunction, run]
# 1                                [thanks, for, lyft, credit, can, not, use, cause, they, do, not, offer, wheelchair, vans, in, pdx, disapointed, getthanked]
# 2                                                                                                                                    [bihday, your, majesty]
# 3                                                                                                [model, love, you, take, with, you, all, the, time, in, ur]
# 4                                                                                                                     [factsguide, society, now, motivation]
# ...                                                                                                                                                      ...
# 49154                                               [thought, factory, left, right, polarisation, trump, uselections, leadership, politics, brexit, blm, gt]
# 49155                                                                [feeling, like, mermaid, hairflip, neverready, formal, wedding, gown, dresses, mermaid]
# 49156  [hillary, campaigned, today, in, ohio, omg, amp, used, words, like, assets, amp, liability, never, once, did, clinton, say, thee, word, radicaliza...
# 49157                                       [happy, at, work, conference, right, mindset, leads, to, culture, of, development, organizations, work, mindset]
# 49158                                                                                      [my, song, so, glad, free, download, shoegaze, newmusic, newsong]
#
#                                                                                                                            tweet_token_filtered  \
# 0                                                                               [father, dysfunctional, selfish, drags, kids, dysfunction, run]
# 1                                                     [thanks, lyft, credit, use, cause, offer, wheelchair, vans, pdx, disapointed, getthanked]
# 2                                                                                                                             [bihday, majesty]
# 3                                                                                                                 [model, love, take, time, ur]
# 4                                                                                                             [factsguide, society, motivation]
# ...                                                                                                                                         ...
# 49154                                  [thought, factory, left, right, polarisation, trump, uselections, leadership, politics, brexit, blm, gt]
# 49155                                                   [feeling, like, mermaid, hairflip, neverready, formal, wedding, gown, dresses, mermaid]
# 49156  [hillary, campaigned, today, ohio, omg, amp, used, words, like, assets, amp, liability, never, clinton, say, thee, word, radicalization]
# 49157                                      [happy, work, conference, right, mindset, leads, culture, development, organizations, work, mindset]
# 49158                                                                                 [song, glad, free, download, shoegaze, newmusic, newsong]
#
#                                                                                                                  tweet_stemmed  \
# 0                                                                        [father, dysfunct, selfish, drag, kid, dysfunct, run]
# 1                                           [thank, lyft, credit, use, caus, offer, wheelchair, van, pdx, disapoint, getthank]
# 2                                                                                                            [bihday, majesti]
# 3                                                                                                [model, love, take, time, ur]
# 4                                                                                                  [factsguid, societi, motiv]
# ...                                                                                                                        ...
# 49154                             [thought, factori, left, right, polaris, trump, uselect, leadership, polit, brexit, blm, gt]
# 49155                                           [feel, like, mermaid, hairflip, neverreadi, formal, wed, gown, dress, mermaid]
# 49156  [hillari, campaign, today, ohio, omg, amp, use, word, like, asset, amp, liabil, never, clinton, say, thee, word, radic]
# 49157                                       [happi, work, confer, right, mindset, lead, cultur, develop, organ, work, mindset]
# 49158                                                                   [song, glad, free, download, shoegaz, newmus, newsong]
#
#                                                                                                                              tweet_lemmatized
# 0                                                                               [father, dysfunctional, selfish, drag, kid, dysfunction, run]
# 1                                                    [thanks, lyft, credit, use, cause, offer, wheelchair, van, pdx, disapointed, getthanked]
# 2                                                                                                                           [bihday, majesty]
# 3                                                                                                               [model, love, take, time, ur]
# 4                                                                                                           [factsguide, society, motivation]
# ...                                                                                                                                       ...
# 49154                                [thought, factory, left, right, polarisation, trump, uselections, leadership, politics, brexit, blm, gt]
# 49155                                                   [feeling, like, mermaid, hairflip, neverready, formal, wedding, gown, dress, mermaid]
# 49156  [hillary, campaigned, today, ohio, omg, amp, used, word, like, asset, amp, liability, never, clinton, say, thee, word, radicalization]
# 49157                                      [happy, work, conference, right, mindset, lead, culture, development, organization, work, mindset]
# 49158                                                                               [song, glad, free, download, shoegaze, newmusic, newsong]
#
# [49159 rows x 8 columns]

# %% [markdown]
# 14. Сохраним результат предобработки в pickle-файл.

# %%
# %%time
df.to_pickle(PROCESSED_PATH)
# Out:
# Wall time: 9 s

# %%
# Проверка
# %time df_from_pickle = pd.read_pickle(PROCESSED_PATH)
# Out:
# Wall time: 1.13 s

# %%
df_from_pickle
# Out:
#           id  label  \
# 0          1    0.0
# 1          2    0.0
# 2          3    0.0
# 3          4    0.0
# 4          5    0.0
# ...      ...    ...
# 49154  49155    NaN
# 49155  49156    NaN
# 49156  49157    NaN
# 49157  49158    NaN
# 49158  49159    NaN
#
#                                                                                                                                                    tweet  \
# 0                                                  @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1                             @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                                                    bihday your majesty
# 3                                                                 #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                                                 factsguide: society now    #motivation
# ...                                                                                                                                                  ...
# 49154                                       thought factory: left-right polarisation! #trump #uselections2016 #leadership #politics  #brexit #blm &gt;3
# 49155                                                   feeling like a mermaid ð #hairflip #neverready #formal #wedding #gown #dresses #mermaid  â¦
# 49156  #hillary #campaigned today in #ohio((omg)) &amp; used words like "assets&amp;liability" never once did #clinton say thee(word) #radicalization
# 49157                                           happy, at work conference: right mindset leads to culture-of-development organizations    #work #mindset
# 49158                                                                                   my   song "so glad" free download!  #shoegaze #newmusic #newsong
#
#                                                                                                                                     text  \
# 0                                              when father is dysfunctional and is so selfish he drags his kids into his dysfunction run
# 1                                thanks for lyft credit cannot use cause they do not offer wheelchair vans in pdx disapointed getthanked
# 2                                                                                                                    bihday your majesty
# 3                                                                                        model love you take with you all the time in ur
# 4                                                                                                      factsguide society now motivation
# ...                                                                                                                                  ...
# 49154                                        thought factory left right polarisation trump uselections leadership politics brexit blm gt
# 49155                                                       feeling like mermaid hairflip neverready formal wedding gown dresses mermaid
# 49156  hillary campaigned today in ohio omg amp used words like assets amp liability never once did clinton say thee word radicalization
# 49157                                  happy at work conference right mindset leads to culture of development organizations work mindset
# 49158                                                                            my song so glad free download shoegaze newmusic newsong
#
#                                                                                                                                                  tweet_token  \
# 0                                                 [when, father, is, dysfunctional, and, is, so, selfish, he, drags, his, kids, into, his, dysfunction, run]
# 1                                [thanks, for, lyft, credit, can, not, use, cause, they, do, not, offer, wheelchair, vans, in, pdx, disapointed, getthanked]
# 2                                                                                                                                    [bihday, your, majesty]
# 3                                                                                                [model, love, you, take, with, you, all, the, time, in, ur]
# 4                                                                                                                     [factsguide, society, now, motivation]
# ...                                                                                                                                                      ...
# 49154                                               [thought, factory, left, right, polarisation, trump, uselections, leadership, politics, brexit, blm, gt]
# 49155                                                                [feeling, like, mermaid, hairflip, neverready, formal, wedding, gown, dresses, mermaid]
# 49156  [hillary, campaigned, today, in, ohio, omg, amp, used, words, like, assets, amp, liability, never, once, did, clinton, say, thee, word, radicaliza...
# 49157                                       [happy, at, work, conference, right, mindset, leads, to, culture, of, development, organizations, work, mindset]
# 49158                                                                                      [my, song, so, glad, free, download, shoegaze, newmusic, newsong]
#
#                                                                                                                            tweet_token_filtered  \
# 0                                                                               [father, dysfunctional, selfish, drags, kids, dysfunction, run]
# 1                                                     [thanks, lyft, credit, use, cause, offer, wheelchair, vans, pdx, disapointed, getthanked]
# 2                                                                                                                             [bihday, majesty]
# 3                                                                                                                 [model, love, take, time, ur]
# 4                                                                                                             [factsguide, society, motivation]
# ...                                                                                                                                         ...
# 49154                                  [thought, factory, left, right, polarisation, trump, uselections, leadership, politics, brexit, blm, gt]
# 49155                                                   [feeling, like, mermaid, hairflip, neverready, formal, wedding, gown, dresses, mermaid]
# 49156  [hillary, campaigned, today, ohio, omg, amp, used, words, like, assets, amp, liability, never, clinton, say, thee, word, radicalization]
# 49157                                      [happy, work, conference, right, mindset, leads, culture, development, organizations, work, mindset]
# 49158                                                                                 [song, glad, free, download, shoegaze, newmusic, newsong]
#
#                                                                                                                  tweet_stemmed  \
# 0                                                                        [father, dysfunct, selfish, drag, kid, dysfunct, run]
# 1                                           [thank, lyft, credit, use, caus, offer, wheelchair, van, pdx, disapoint, getthank]
# 2                                                                                                            [bihday, majesti]
# 3                                                                                                [model, love, take, time, ur]
# 4                                                                                                  [factsguid, societi, motiv]
# ...                                                                                                                        ...
# 49154                             [thought, factori, left, right, polaris, trump, uselect, leadership, polit, brexit, blm, gt]
# 49155                                           [feel, like, mermaid, hairflip, neverreadi, formal, wed, gown, dress, mermaid]
# 49156  [hillari, campaign, today, ohio, omg, amp, use, word, like, asset, amp, liabil, never, clinton, say, thee, word, radic]
# 49157                                       [happi, work, confer, right, mindset, lead, cultur, develop, organ, work, mindset]
# 49158                                                                   [song, glad, free, download, shoegaz, newmus, newsong]
#
#                                                                                                                              tweet_lemmatized
# 0                                                                               [father, dysfunctional, selfish, drag, kid, dysfunction, run]
# 1                                                    [thanks, lyft, credit, use, cause, offer, wheelchair, van, pdx, disapointed, getthanked]
# 2                                                                                                                           [bihday, majesty]
# 3                                                                                                               [model, love, take, time, ur]
# 4                                                                                                           [factsguide, society, motivation]
# ...                                                                                                                                       ...
# 49154                                [thought, factory, left, right, polarisation, trump, uselections, leadership, politics, brexit, blm, gt]
# 49155                                                   [feeling, like, mermaid, hairflip, neverready, formal, wedding, gown, dress, mermaid]
# 49156  [hillary, campaigned, today, ohio, omg, amp, used, word, like, asset, amp, liability, never, clinton, say, thee, word, radicalization]
# 49157                                      [happy, work, conference, right, mindset, lead, culture, development, organization, work, mindset]
# 49158                                                                               [song, glad, free, download, shoegaze, newmusic, newsong]
#
# [49159 rows x 8 columns]
